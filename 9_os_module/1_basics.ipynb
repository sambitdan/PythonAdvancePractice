# %%
import os

# %%
os.getcwd() # get current working directory which will show the main root folder is hosted
# Out:
# '/Users/sambitdan/Documents/PythonAdvancePractice/9_os_module'

# %%
# to get absolute path in .ipynb we use
from pathlib import Path
print(Path.cwd())
# Out:
# /Users/sambitdan/Documents/PythonAdvancePractice/9_os_module

# %%
print(os.environ.get("JPY_KERNEL_ID"))
# Out:
# None
